# %%
import pandas as pd

# %%
data = pd.read_csv('v2.csv')
data.head()
# Out:
#             post_id                                               text  \
# 0  5168796143190805  I am 28,f and feel like I'm going to be single...
# 1  5168795226524230  Advice needed. My boyfriend is an ideal man: T...
# 2  5168793769857709  Hi ,\n\nI'm 20 and consider myself straight. B...
# 3  5168793149857771  I am the one who write on confession #96104. F...
# 4  5168792489857837  I wish he knows how tired i am being in this r...
#
#                                            post_text shared_text  \
# 0  I am 28,f and feel like I'm going to be single...         NaN
# 1  Advice needed. My boyfriend is an ideal man: T...         NaN
# 2  Hi ,\n\nI'm 20 and consider myself straight. B...         NaN
# 3  I am the one who write on confession #96104. F...         NaN
# 4  I wish he knows how tired i am being in this r...         NaN
#
#                   time image video video_thumbnail  video_id  num_reactions  \
# ...

# %%
import string
data[]
